# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
telecom_df1=pd.read_csv(r'C:\Users\gslon\Desktop\Naresh IT\Untitled Folder\telecom_churn_data.csv')
telecom_df1
# Out:
#       year  customer_id  phone_no  gender  age  no_of_days_subscribed  \
# 0     2015       100198  409-8743  Female   36                     62
# 1     2015       100643  340-5930  Female   39                    149
# 2     2015       100756  372-3750  Female   65                    126
# 3     2015       101595  331-4902  Female   24                    131
# 4     2015       101653  351-8398  Female   40                    191
# ...    ...          ...       ...     ...  ...                    ...
# 1995  2015       997132  385-7387  Female   54                     75
# 1996  2015       998086  383-9255    Male   45                    127
# 1997  2015       998474  353-2080     NaN   53                     94
# 1998  2015       998934  359-7788    Male   40                     94
# 1999  2015       999961  414-1496    Male   37                     73
#
#      multi_screen mail_subscribed  weekly_mins_watched  minimum_daily_mins  \
# ...

# %%
cdf=telecom_df1['mail_subscribed'].value_counts()
keys=cdf.keys()
value=cdf.values
cols=['Label','count']
df=pd.DataFrame(zip(keys,value), columns=cols)
df.to_csv('mail.csv',index=False)

# %%
import seaborn as sns
order_mail=['yes','no']
plt.figure(figsize=(5,5))
sns.countplot(data=telecom_df1, x='mail_subscribed', order=order_mail)
# Out:
# <Axes: xlabel='mail_subscribed', ylabel='count'>

# %%
import os
cwd = os.getcwd()
print(cwd)
# Out:
# C:\Users\gslon\Desktop\Naresh IT\Untitled Folder
