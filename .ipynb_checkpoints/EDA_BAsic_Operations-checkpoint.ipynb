# %%
a=1
b=2
c=a+b
c
# Out:
# 3

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path=r"C:\Users\gslon\Desktop\Naresh IT\Untitled Folder\DataFiles\telecom_churn_data.csv"

# %%
telecom_df=pd.read_csv(path)
telecom_df
# Out:
#       year  customer_id  phone_no  gender  age  no_of_days_subscribed  \
# 0     2015       100198  409-8743  Female   36                     62
# 1     2015       100643  340-5930  Female   39                    149
# 2     2015       100756  372-3750  Female   65                    126
# 3     2015       101595  331-4902  Female   24                    131
# 4     2015       101653  351-8398  Female   40                    191
# ...    ...          ...       ...     ...  ...                    ...
# 1995  2015       997132  385-7387  Female   54                     75
# 1996  2015       998086  383-9255    Male   45                    127
# 1997  2015       998474  353-2080     NaN   53                     94
# 1998  2015       998934  359-7788    Male   40                     94
# 1999  2015       999961  414-1496    Male   37                     73
#
#      multi_screen mail_subscribed  weekly_mins_watched  minimum_daily_mins  \
# ...

# %% [markdown]
#  - Shape
#
# - head
#
# - tail
#
# - dtypes
#
# - isnull
#
# - insull().sum
#
# - isna
#
# - info

# %%
telecom_df.isna() #isna ann isnull both are same
# Out:
#        year  customer_id  phone_no  gender    age  no_of_days_subscribed  \
# 0     False        False     False   False  False                  False
# 1     False        False     False   False  False                  False
# 2     False        False     False   False  False                  False
# 3     False        False     False   False  False                  False
# 4     False        False     False   False  False                  False
# ...     ...          ...       ...     ...    ...                    ...
# 1995  False        False     False   False  False                  False
# 1996  False        False     False   False  False                  False
# 1997  False        False     False    True  False                  False
# 1998  False        False     False   False  False                  False
# 1999  False        False     False   False  False                  False
#
#       multi_screen  mail_subscribed  weekly_mins_watched  minimum_daily_mins  \
# ...

# %%
telecom_df.info() #give all information about dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   year                    2000 non-null   int64
#  1   customer_id             2000 non-null   int64
#  2   phone_no                2000 non-null   object
#  3   gender                  1976 non-null   object
#  4   age                     2000 non-null   int64
#  5   no_of_days_subscribed   2000 non-null   int64
#  6   multi_screen            2000 non-null   object
#  7   mail_subscribed         2000 non-null   object
#  8   weekly_mins_watched     2000 non-null   float64
#  9   minimum_daily_mins      2000 non-null   float64
#  10  maximum_daily_mins      2000 non-null   float64
#  11  weekly_max_night_mins   2000 non-null   int64
#  12  videos_watched          2000 non-null   int64
#  13  maximum_days_inactive   1972 non-null   float64
# ...

# %% [markdown]
# **take**

# %%
telecom_df.take([100,200,300]) #Retrive rows having index 100,200,300
# Out:
#      year  customer_id  phone_no  gender  age  no_of_days_subscribed  \
# 100  2015       138375  354-4577  Female   34                    144
# 200  2015       186513  387-9301    Male   51                     58
# 300  2015       234709  370-9533  Female   38                    138
#
#     multi_screen mail_subscribed  weekly_mins_watched  minimum_daily_mins  \
# 100           no              no               301.65                13.2
# 200           no             yes               360.60                11.2
# 300           no             yes                29.25                 7.9
#
#      maximum_daily_mins  weekly_max_night_mins  videos_watched  \
# 100               34.19                    119               2
# 200               40.87                    108               3
# 300                3.32                    111               1
#
#      maximum_days_inactive  customer_support_calls  churn
# 100                    4.0                       1    0.0
# ...

# %%
telecom_df.take([1,2,3], axis=1)
# Out:
#       customer_id  phone_no  gender
# 0          100198  409-8743  Female
# 1          100643  340-5930  Female
# 2          100756  372-3750  Female
# 3          101595  331-4902  Female
# 4          101653  351-8398  Female
# ...           ...       ...     ...
# 1995       997132  385-7387  Female
# 1996       998086  383-9255    Male
# 1997       998474  353-2080     NaN
# 1998       998934  359-7788    Male
# 1999       999961  414-1496    Male
#
# [2000 rows x 3 columns]

# %%
telecom_df.columns
# Out:
# Index(['year', 'customer_id', 'phone_no', 'gender', 'age',
#        'no_of_days_subscribed', 'multi_screen', 'mail_subscribed',
#        'weekly_mins_watched', 'minimum_daily_mins', 'maximum_daily_mins',
#        'weekly_max_night_mins', 'videos_watched', 'maximum_days_inactive',
#        'customer_support_calls', 'churn'],
#       dtype='object')

# %%
telecom_df.take([2,5,7], axis=1)
# Out:
#       phone_no  no_of_days_subscribed mail_subscribed
# 0     409-8743                     62              no
# 1     340-5930                    149              no
# 2     372-3750                    126              no
# 3     331-4902                    131             yes
# 4     351-8398                    191              no
# ...        ...                    ...             ...
# 1995  385-7387                     75             yes
# 1996  383-9255                    127              no
# 1997  353-2080                     94              no
# 1998  359-7788                     94              no
# 1999  414-1496                     73              no
#
# [2000 rows x 3 columns]

# %% [markdown]
# **Slicing**

# %%
telecom_df.take([2:7], axis=1) # Slicing fail
# Out:
#   Cell In[17], line 1
#     telecom_df.take([2:7], axis=1)
#                       ^
# SyntaxError: invalid syntax

# %%
telecom_df.take([1,2,3], axis=0)
# Out:
#    year  customer_id  phone_no  gender  age  no_of_days_subscribed  \
# 1  2015       100643  340-5930  Female   39                    149
# 2  2015       100756  372-3750  Female   65                    126
# 3  2015       101595  331-4902  Female   24                    131
#
#   multi_screen mail_subscribed  weekly_mins_watched  minimum_daily_mins  \
# 1           no              no               294.45                 7.7
# 2           no              no                87.30                11.9
# 3           no             yes               321.30                 9.5
#
#    maximum_daily_mins  weekly_max_night_mins  videos_watched  \
# 1               33.37                     87               3
# 2                9.89                     91               1
# 3               36.41                    102               4
#
#    maximum_days_inactive  customer_support_calls  churn
# 1                    3.0                       2    0.0
# ...

# %%
telecom_df.take([100,200,300], axis=0)
# Out:
#      year  customer_id  phone_no  gender  age  no_of_days_subscribed  \
# 100  2015       138375  354-4577  Female   34                    144
# 200  2015       186513  387-9301    Male   51                     58
# 300  2015       234709  370-9533  Female   38                    138
#
#     multi_screen mail_subscribed  weekly_mins_watched  minimum_daily_mins  \
# 100           no              no               301.65                13.2
# 200           no             yes               360.60                11.2
# 300           no             yes                29.25                 7.9
#
#      maximum_daily_mins  weekly_max_night_mins  videos_watched  \
# 100               34.19                    119               2
# 200               40.87                    108               3
# 300                3.32                    111               1
#
#      maximum_days_inactive  customer_support_calls  churn
# 100                    4.0                       1    0.0
# ...

# %% [markdown]
# **loc  iloc**

# %%
telecom_df.iloc[<rows>,<columns>]
telecom_df.iloc[start:stop, start:stop]
telecom_df.iloc[start:stop:step, start:stop:step]
telecom_df.iloc[[list of rows], [list of columns]]

# %%
telecom_df.iloc[[100,200,300], [1,2,3]]
# Out:
#      customer_id  phone_no  gender
# 100       138375  354-4577  Female
# 200       186513  387-9301    Male
# 300       234709  370-9533  Female

# %%
telecom_df.iloc[100:105, [2,3,5]]
# Out:
#      phone_no  gender  no_of_days_subscribed
# 100  354-4577  Female                    144
# 101  378-2940  Female                    148
# 102  395-4757    Male                     70
# 103  393-8736    Male                    149
# 104  405-5305  Female                     16

# %%
telecom_df.iloc[100:105, 2:5]
# Out:
#      phone_no  gender  age
# 100  354-4577  Female   34
# 101  378-2940  Female   32
# 102  395-4757    Male   28
# 103  393-8736    Male   48
# 104  405-5305  Female   24

# %%
telecom_df.iloc[[100,200,300], 2:5]
# Out:
#      phone_no  gender  age
# 100  354-4577  Female   34
# 200  387-9301    Male   51
# 300  370-9533  Female   38

# %%
telecom_df.iloc[100:105, [1,2,3]]
# Out:
#      customer_id  phone_no  gender
# 100       138375  354-4577  Female
# 101       138462  378-2940  Female
# 102       138764  395-4757    Male
# 103       138770  393-8736    Male
# 104       139612  405-5305  Female

# %%
telecom_df.iloc[[100,200,300] [:]]
# Out:
#      year  customer_id  phone_no  gender  age  no_of_days_subscribed  \
# 100  2015       138375  354-4577  Female   34                    144
# 200  2015       186513  387-9301    Male   51                     58
# 300  2015       234709  370-9533  Female   38                    138
#
#     multi_screen mail_subscribed  weekly_mins_watched  minimum_daily_mins  \
# 100           no              no               301.65                13.2
# 200           no             yes               360.60                11.2
# 300           no             yes                29.25                 7.9
#
#      maximum_daily_mins  weekly_max_night_mins  videos_watched  \
# 100               34.19                    119               2
# 200               40.87                    108               3
# 300                3.32                    111               1
#
#      maximum_days_inactive  customer_support_calls  churn
# 100                    4.0                       1    0.0
# ...

# %%
telecom_df.iloc[:, [2,5,7]]
# Out:
#       phone_no  no_of_days_subscribed mail_subscribed
# 0     409-8743                     62              no
# 1     340-5930                    149              no
# 2     372-3750                    126              no
# 3     331-4902                    131             yes
# 4     351-8398                    191              no
# ...        ...                    ...             ...
# 1995  385-7387                     75             yes
# 1996  383-9255                    127              no
# 1997  353-2080                     94              no
# 1998  359-7788                     94              no
# 1999  414-1496                     73              no
#
# [2000 rows x 3 columns]

# %%
telecom_df.iloc[[100,200,300]]  #Special case:take only rows
# Out:
#      year  customer_id  phone_no  gender  age  no_of_days_subscribed  \
# 100  2015       138375  354-4577  Female   34                    144
# 200  2015       186513  387-9301    Male   51                     58
# 300  2015       234709  370-9533  Female   38                    138
#
#     multi_screen mail_subscribed  weekly_mins_watched  minimum_daily_mins  \
# 100           no              no               301.65                13.2
# 200           no             yes               360.60                11.2
# 300           no             yes                29.25                 7.9
#
#      maximum_daily_mins  weekly_max_night_mins  videos_watched  \
# 100               34.19                    119               2
# 200               40.87                    108               3
# 300                3.32                    111               1
#
#      maximum_days_inactive  customer_support_calls  churn
# 100                    4.0                       1    0.0
# ...

# %%
telecom_df.iloc[:] #Special case: All data will come
# Out:
#       year  customer_id  phone_no  gender  age  no_of_days_subscribed  \
# 0     2015       100198  409-8743  Female   36                     62
# 1     2015       100643  340-5930  Female   39                    149
# 2     2015       100756  372-3750  Female   65                    126
# 3     2015       101595  331-4902  Female   24                    131
# 4     2015       101653  351-8398  Female   40                    191
# ...    ...          ...       ...     ...  ...                    ...
# 1995  2015       997132  385-7387  Female   54                     75
# 1996  2015       998086  383-9255    Male   45                    127
# 1997  2015       998474  353-2080     NaN   53                     94
# 1998  2015       998934  359-7788    Male   40                     94
# 1999  2015       999961  414-1496    Male   37                     73
#
#      multi_screen mail_subscribed  weekly_mins_watched  minimum_daily_mins  \
# ...

# %%
telecom_df.iloc[:,2]
# Out:
# 0       409-8743
# 1       340-5930
# 2       372-3750
# 3       331-4902
# 4       351-8398
#           ...
# 1995    385-7387
# 1996    383-9255
# 1997    353-2080
# 1998    359-7788
# 1999    414-1496
# Name: phone_no, Length: 2000, dtype: object

# %%
telecom_df.iloc[:,[2]] # DataFrame will come
# Out:
#       phone_no
# 0     409-8743
# 1     340-5930
# 2     372-3750
# 3     331-4902
# 4     351-8398
# ...        ...
# 1995  385-7387
# 1996  383-9255
# 1997  353-2080
# 1998  359-7788
# 1999  414-1496
#
# [2000 rows x 1 columns]

# %%
telecom_df.columns
# Out:
# Index(['year', 'customer_id', 'phone_no', 'gender', 'age',
#        'no_of_days_subscribed', 'multi_screen', 'mail_subscribed',
#        'weekly_mins_watched', 'minimum_daily_mins', 'maximum_daily_mins',
#        'weekly_max_night_mins', 'videos_watched', 'maximum_days_inactive',
#        'customer_support_calls', 'churn'],
#       dtype='object')

# %%
telecom_df.iloc[:,2]
# Out:
# 0       409-8743
# 1       340-5930
# 2       372-3750
# 3       331-4902
# 4       351-8398
#           ...
# 1995    385-7387
# 1996    383-9255
# 1997    353-2080
# 1998    359-7788
# 1999    414-1496
# Name: phone_no, Length: 2000, dtype: object

# %%
telecom_df.loc[:, 'phone_no']
# Out:
# 0       409-8743
# 1       340-5930
# 2       372-3750
# 3       331-4902
# 4       351-8398
#           ...
# 1995    385-7387
# 1996    383-9255
# 1997    353-2080
# 1998    359-7788
# 1999    414-1496
# Name: phone_no, Length: 2000, dtype: object

# %%
telecom_df.loc[:, ['phone_no']]
# Out:
#       phone_no
# 0     409-8743
# 1     340-5930
# 2     372-3750
# 3     331-4902
# 4     351-8398
# ...        ...
# 1995  385-7387
# 1996  383-9255
# 1997  353-2080
# 1998  359-7788
# 1999  414-1496
#
# [2000 rows x 1 columns]

# %%
telecom_df.loc[:, ['phone_no', 'maximum_days_inactive']]
# Out:
#       phone_no  maximum_days_inactive
# 0     409-8743                    4.0
# 1     340-5930                    3.0
# 2     372-3750                    4.0
# 3     331-4902                    3.0
# 4     351-8398                    3.0
# ...        ...                    ...
# 1995  385-7387                    4.0
# 1996  383-9255                    3.0
# 1997  353-2080                    5.0
# 1998  359-7788                    NaN
# 1999  414-1496                    3.0
#
# [2000 rows x 2 columns]

# %%
telecom_df.loc[100:105, ['phone_no', 'maximum_days_inactive']]
# Out:
#      phone_no  maximum_days_inactive
# 100  354-4577                    4.0
# 101  378-2940                    4.0
# 102  395-4757                    3.0
# 103  393-8736                    3.0
# 104  405-5305                    NaN
# 105  407-7258                    3.0

# %%
telecom_df.loc[[100,200,300], ['phone_no', 'maximum_days_inactive']]
# Out:
#      phone_no  maximum_days_inactive
# 100  354-4577                    4.0
# 200  387-9301                    4.0
# 300  370-9533                    3.0

# %%
telecom_df.loc[[100,200,300] [:]]
# Out:
#      year  customer_id  phone_no  gender  age  no_of_days_subscribed  \
# 100  2015       138375  354-4577  Female   34                    144
# 200  2015       186513  387-9301    Male   51                     58
# 300  2015       234709  370-9533  Female   38                    138
#
#     multi_screen mail_subscribed  weekly_mins_watched  minimum_daily_mins  \
# 100           no              no               301.65                13.2
# 200           no             yes               360.60                11.2
# 300           no             yes                29.25                 7.9
#
#      maximum_daily_mins  weekly_max_night_mins  videos_watched  \
# 100               34.19                    119               2
# 200               40.87                    108               3
# 300                3.32                    111               1
#
#      maximum_days_inactive  customer_support_calls  churn
# 100                    4.0                       1    0.0
# ...
